# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn import linear_model

# %%
import os
os.chdir(r'C:\Users\Prerna\Desktop\python_csv')
data=pd.read_csv('homeprices.csv')
data
#data(1:3)
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(data.Area,data.Price)

# %%
data_new=data.drop('Price',axis='columns')
data_new
# Out:
#    Area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(data_new,data.Price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
import os
os.chdir(r'C:\Users\Prerna\Desktop\python_csv')

# %%
df=pd.read_csv('Area.csv')
df
# Out:
#     Area
# 0   1000
# 1   1500
# 2   2300
# 3   4500
# 4   5490
# 5   3540
# 6   4120
# 7   3460
# 8   4750
# 9   2300
# 10  9000

# %%
p=model.predict(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-45dbdaff2f37> in <module>
# ----> 1 p=model.predict(df)
#
# NameError: name 'model' is not defined

# %%
import os
os.chdir(r'C:\Users\Prerna\Desktop\python_csv')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df['prices']=p
df
df.to_csv('Area.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f13569de0406> in <module>
# ----> 1 df['prices']=p
#       2 df
#       3 df.to_csv('Area.csv')
#
# NameError: name 'p' is not defined

# %%
df=pd.read_csv("canada_income.csv")
df
# Out:
#     year    per_capita
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import os
os.chdir(r'C:\Users\Prerna\Desktop\python_csv')
os.getcwd()
df=pd.read_csv('canada_income.csv')
df
# Out:
#     year    per_capita
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year,df.per_capita)

# %%
new_df=df.drop('per_capita',axis='columns')
new_df
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
model=linear_model.LinearRegression()
model.fit(new_df,df.per_capita)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict([[2020]])
# Out:
# array([41288.69409442])

# %% [markdown]
# #Linear regression using multiple varaibles

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import os
os.getcwd()
os.chdir(r'C:\Users\Prerna\Desktop\python_csv')
df=pd.read_csv('homeprices_mv.csv')
df
# Out:
#    area  bedroom  age   price
# 0  2600      3.0   20  550000
# 1  3000      4.0   15  565000
# 2  3200      NaN   18  610000
# 3  3600      3.0   30  595000
# 4  4000      5.0    8  760000
# 5  4100      6.0    8  810000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,hue='area',height=3)
# Out:
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import math
df.bedroom.median()
plt.scatter(df.area,df.price)

# %%
df.bedroom=df.bedroom.fillna(df.bedroom.median())
df
# Out:
#    area  bedroom  age   price
# 0  2600      3.0   20  550000
# 1  3000      4.0   15  565000
# 2  3200      4.0   18  610000
# 3  3600      3.0   30  595000
# 4  4000      5.0    8  760000
# 5  4100      6.0    8  810000

# %%
new_df=df.drop('price',axis='columns')
new_df
# Out:
#    area  bedroom  age
# 0  2600      3.0   20
# 1  3000      4.0   15
# 2  3200      4.0   18
# 3  3600      3.0   30
# 4  4000      5.0    8
# 5  4100      6.0    8

# %%
model=linear_model.LinearRegression()
model.fit(new_df,df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict([[3000,3,10]])
# Out:
# array([595359.7888393])
